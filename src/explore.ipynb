# %% [markdown]
# # Explore here

# %% [markdown]
# PASO 1 #cargar la base de datos#

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
medical = pd.read_csv("https://raw.githubusercontent.com/4GeeksAcademy/linear-regression-project-tutorial/main/medical_insurance_cost.csv", sep = ",")
medical.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
medical
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# PASO 2 #REALIZAR EDA#

# %%
print("Valores nulos por columna:")
print(medical.isnull().sum())
# Out:
# Valores nulos por columna:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
print("\nDescripción estadística de las variables numéricas:")
print(medical.describe())
# Out:
# Descripción estadística de las variables numéricas:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
print("\nTipos de datos en el dataset:")
print(medical.dtypes)
# Out:
# Tipos de datos en el dataset:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
medical.columns 
medical.columns.str.strip()
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
print(medical.columns)
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
print (medical.columns.tolist())
# Out:
# ['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges']

# %%
type(medical)
# Out:
# pandas.core.frame.DataFrame

# %%
print (medical.columns.tolist())
# Out:
# ['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges']

# %%
print (medical ['charges'] .dtype)
# Out:
# float64

# %%
print ('charges' in medical.columns)
# Out:
# True

# %%
for col in medical.columns:
    print(repr(col))
# Out:
# 'age'
# 'sex'
# 'bmi'
# 'children'
# 'smoker'
# 'region'
# 'charges'

# %%
medical.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
medical.columns = medical.columns.str.strip()  # elimina espacios al inicio y final

# %%
print(medical.columns.tolist())
print('charges' in medical.columns)  # debería dar True
# Out:
# ['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges']
# True

# %%
medical = pd.read_csv("https://raw.githubusercontent.com/4GeeksAcademy/linear-regression-project-tutorial/main/medical_insurance_cost.csv")

# %%
medical.info()
print("\nValores nulos por columna:")
print(medical.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB
#
# Valores nulos por columna:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
print(medical.describe())
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
print(medical.select_dtypes(include='object').describe())
# Out:
#          sex smoker     region
# count   1338   1338       1338
# unique     2      2          4
# top     male     no  southeast
# freq     676   1064        364

# %% [markdown]
# DISTRIBUCION VARIABLES NUMERICAS

# %%
import matplotlib.pyplot as plt
import seaborn as sns

num_cols = medical.select_dtypes(include=['int64', 'float64']).columns.tolist()

plt.figure(figsize=(15,10))
for i, col in enumerate(num_cols):
    plt.subplot(2, 3, i+1)
    sns.histplot(medical[col], kde=True)
    plt.title(f'Distribución de {col}')
plt.tight_layout()
plt.show()

# %% [markdown]
# VARIABLES CATEGORICAS

# %%
cat_cols = medical.select_dtypes(include='object').columns.tolist()

for col in cat_cols:
    print(f"Variable: {col}")
    print(medical[col].value_counts())
print("-"*40)
# Out:
# Variable: sex
# sex
# male      676
# female    662
# Name: count, dtype: int64
# Variable: smoker
# smoker
# no     1064
# yes     274
# Name: count, dtype: int64
# Variable: region
# region
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: count, dtype: int64
# ----------------------------------------

# %% [markdown]
# CORRELACION ENTRE VARIABLES NUMERICAS

# %%
plt.figure(figsize=(8,6))
sns.heatmap(medical[num_cols].corr(), annot=True, cmap='coolwarm')
plt.title("Mapa de calor de correlaciones")
plt.show()

# %% [markdown]
# Análisis específico con la variable objetivo charges
#
# Relación entre variables categóricas y charges (boxplots)

# %%
for col in cat_cols:
    plt.figure(figsize=(8,5))
    sns.boxplot(x=medical[col], y=medical['charges'])
    plt.title(f'Relación entre {col} y charges')
plt.show()

# %% [markdown]
# Relación entre variables numéricas y charges (scatterplots)

# %%
for col in num_cols:
    if col != 'charges':
        plt.figure(figsize=(8,5))
        sns.scatterplot(x=medical[col], y=medical['charges'])
        plt.title(f'Relación entre {col} y charges')
plt.show()

# %% [markdown]
# DIVIDIR EL DATASET EN ENTRENAMIENTO Y PRUEBA (TRAIN/TEST)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Variables a usar
num_vars = ['age', 'bmi', 'children']
cat_vars = ['sex', 'smoker', 'region']

# Crear DataFrame solo con las variables seleccionadas + objetivo
data = medical[num_vars + cat_vars + ['charges']]

# One-hot encoding para variables categóricas
data_encoded = pd.get_dummies(data, columns=cat_vars, drop_first=True)

# Dividir en train y test (80% train, 20% test)
train, test = train_test_split(data_encoded, test_size=0.2, random_state=42)

print(f"Tamaño del conjunto de entrenamiento: {train.shape}")
print(f"Tamaño del conjunto de prueba:{test.shape}")
# Out:
# Tamaño del conjunto de entrenamiento: (1070, 9)
# Tamaño del conjunto de prueba:(268, 9)

# %%
# Separar variables predictoras y variable objetivo
X_train = train.drop('charges', axis=1)
y_train = train['charges']

X_test = test.drop('charges', axis=1)
y_test =test['charges']

# %% [markdown]
# PASO 3:MODELO REGRESION LINEAL

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Crear el modelo de regresión lineal
model = LinearRegression()

# Entrenar el modelo con el conjunto de entrenamiento
model.fit(X_train, y_train)

# Predecir los valores en el conjunto de prueba
y_pred = model.predict(X_test)

# Evaluar el modelo
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Error cuadrático medio (MSE): {mse:.2f}")
print(f"Coeficiente de determinación (R2):{r2:.2f}")
# Out:
# Error cuadrático medio (MSE): 33596915.85
# Coeficiente de determinación (R2):0.78

# %% [markdown]
# Este tipo de modelo no tiene parametros para realizar optimizacion.
